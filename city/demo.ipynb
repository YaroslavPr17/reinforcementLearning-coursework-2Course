# %%
from Agent.agent import Agent

# %%
agent = Agent(5, 0)
# Out:
# Empty city was built.
# Ground was built.
# Intersections were built.
# Roads were built.
# Intersections were finalized.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [00:55<00:00,  1.73it/s]
# Transition dictionary was built.
# sys.getsizeof(self.states) = 732808
# sys.getsizeof(self.P) = 5242968

# %%
agent.extract_q_table(Agent.load_compressed_q_table_from_file('compressed_q_table'))
# Out:
# Q_table extraction progress: 100%|█████████████████████████████████████████████| 89012/89012 [00:19<00:00, 4496.61it/s]

# %%
agent.perform(1000)
# Out:
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=11, axis1=12)
# DestCoord(axis0=13, axis1=25)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [127, 0, 0, 0, 199, 54]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 5, lane = 1
# [1, 48, 50, 0, 1, 71]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = None
# [194, 0, 0, 234, 0, 0]
#
# Episode 0: sum_reward = -31390
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=18, axis1=8)
# DestCoord(axis0=14, axis1=8)
# self.current_lane = 2
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 1
# [114, 0, 0, 13, 214, 0]
#
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [17, 0, 0, 1, 21, 0]
#
# Episode 1: sum_reward = 105320
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=19, axis1=13)
# DestCoord(axis0=19, axis1=15)
# self.current_lane = 1
# [[G()                  X(2320,7)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [19, 0, 0, 12, 14, 15]
#
# action = 5, lane = 1
# [3, 0, 0, 0, 0, 12]
#
# action = 4, lane = 0
# [3, 1, 0, 3, 18, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 25, 0]
#
# Episode 2: sum_reward = 78940
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=9, axis1=8)
# DestCoord(axis0=9, axis1=20)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# action = 2, lane = 0
# [1, 1, 70, 1, 2, 13]
#
# action = 3, lane = 1
# [19, 0, 0, 31, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 2
# [18, 4, 0, 23, 0, 0]
#
# action = 4, lane = 1
# [138, 0, 0, 3, 267, 0]
#
# action = 0, lane = 1
# [20, 0, 10, 0, 17, 0]
#
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 2, lane = 0
# [0, 3, 71, 0, 0, 6]
#
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# Episode 3: sum_reward = 77500
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=9)
# DestCoord(axis0=13, axis1=7)
# self.current_lane = 1
# [[R([0, 1, 2]|[2, 1, 0] X(0023,5)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 1, lane = 2
# [2, 51, 3, 2, 1, 4]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 2, lane = 0
# [15, 0, 38, 0, 14, 6]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# Episode 4: sum_reward = 92710
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=19, axis1=10)
# DestCoord(axis0=22, axis1=14)
# self.current_lane = 2
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 1
# [0, 0, 0, 0, 29, 0]
#
# action = 4, lane = 0
# [136, 0, 0, 0, 185, 4]
#
# action = 5, lane = 1
# [0, 0, 1, 0, 0, 5]
#
# action = 0, lane = 1
# [14, 1, 0, 0, 13, 0]
#
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 2
# [15, 0, 0, 17, 0, 0]
#
# action = 4, lane = 1
# [130, 0, 0, 11, 207, 32]
#
# action = 4, lane = 0
# [16, 0, 19, 0, 20, 5]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [121, 0, 0, 6, 215, 20]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 5, lane = 0
# [0, 1, 0, 0, 0, 5]
#
# action = 0, lane = 0
# [2, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 1, lane = 2
# [18, 19, 0, 12, 0, 1]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 18, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# Episode 5: sum_reward = 75505
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=15, axis1=14)
# DestCoord(axis0=21, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [130, 0, 0, 11, 207, 32]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [121, 0, 0, 6, 215, 20]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 2, lane = 0
# [1, 8, 61, 1, 1, 4]
#
# action = 3, lane = 2
# [17, 0, 0, 49, 0, 0]
#
# action = 4, lane = 1
# [103, 0, 0, 1, 201, 0]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 1, lane = 2
# [18, 19, 0, 12, 0, 1]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 18, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# Episode 6: sum_reward = 71145
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=13, axis1=6)
# DestCoord(axis0=10, axis1=20)
# self.current_lane = 0
# [[G()                  R([0]|[0]            G()                 ]
#  [G()                  R([0]|[0]            G()                 ]]
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# action = 2, lane = 0
# [0, 20, 28, 0, 1, 6]
#
# action = 3, lane = 1
# [8, 0, 0, 17, 0, 2]
#
# action = 4, lane = 0
# [77, 0, 0, 4, 133, 1]
#
# action = 3, lane = 2
# [10, 4, 0, 14, 0, 7]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 40, 2]
#
# action = 4, lane = 0
# [76, 0, 0, 3, 172, 7]
#
# action = 3, lane = 1
# [125, 0, 0, 168, 0, 7]
#
# action = 1, lane = 1
# [3, 78, 2, 0, 0, 16]
#
# action = 4, lane = 0
# [15, 4, 0, 0, 18, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 3, lane = 2
# [6, 6, 0, 9, 6, 0]
#
# action = 4, lane = 1
# [123, 0, 0, 2, 189, 0]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 19, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 1, lane = 3
# [1, 53, 3, 1, 1, 4]
#
# action = 0, lane = 3
# [20, 0, 0, 0, 20, 0]
#
# action = 4, lane = 2
# [114, 0, 0, 13, 214, 0]
#
# action = 4, lane = 1
# [62, 0, 0, 54, 107, 0]
#
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# action = 3, lane = 1
# [18, 2, 0, 20, 0, 0]
#
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# Episode 7: sum_reward = 70445
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=11, axis1=14)
# DestCoord(axis0=10, axis1=20)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = None
# [194, 0, 0, 234, 0, 0]
#
# Episode 8: sum_reward = -19840
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=13, axis1=6)
# DestCoord(axis0=8, axis1=20)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0]|[0]            G()                 ]]
# action = 0, lane = 0
# [68, 0, 0, 35, 0, 20]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 5, lane = 1
# [3, 9, 8, 2, 2, 117]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [0, 0, 0, 0, 67, 0]
#
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# action = 1, lane = 1
# [0, 38, 7, 0, 1, 2]
#
# action = 4, lane = 0
# [10, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# action = 2, lane = 0
# [23, 0, 37, 0, 13, 4]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 4, lane = 0
# [15, 4, 0, 0, 18, 0]
#
# action = 3, lane = None
# [167, 0, 0, 176, 0, 0]
#
# Episode 9: sum_reward = -34330
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=10)
# DestCoord(axis0=21, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 1, lane = 2
# [0, 75, 1, 1, 2, 11]
#
# action = 0, lane = 2
# [38, 2, 0, 0, 25, 0]
#
# action = 4, lane = 1
# [85, 0, 0, 4, 202, 0]
#
# action = 4, lane = 0
# [122, 0, 0, 82, 125, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 4, lane = 0
# [5, 2, 0, 19, 32, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 0, lane = 1
# [13, 0, 0, 0, 12, 0]
#
# action = 4, lane = 0
# [85, 0, 0, 4, 202, 0]
#
# action = 3, lane = 2
# [26, 3, 0, 36, 0, 0]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 15, 0]
#
# action = 4, lane = 0
# [85, 0, 0, 4, 202, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 1, lane = 1
# [2, 49, 1, 0, 1, 7]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 6, 14, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 4, lane = 0
# [16, 0, 19, 0, 20, 5]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 3, lane = 1
# [195, 0, 0, 213, 0, 82]
#
# action = 5, lane = 0
# [0, 25, 1, 0, 0, 37]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 1, lane = 2
# [18, 19, 0, 12, 0, 1]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 18, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# Episode 10: sum_reward = 59615
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=18, axis1=12)
# DestCoord(axis0=8, axis1=8)
# self.current_lane = 0
# [[R([0, 1, 2]|[2, 1, 0] X(2320,7)            R([0, 1]|[2, 1, 0]  ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [139, 0, 0, 144, 0, 29]
#
# action = 2, lane = 0
# [1, 47, 48, 0, 1, 33]
#
# action = 0, lane = 0
# [12, 0, 12, 11, 0, 4]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 0, lane = 1
# [31, 0, 0, 15, 23, 0]
#
# action = 4, lane = 0
# [81, 0, 0, 0, 135, 3]
#
# action = 2, lane = 0
# [1, 3, 45, 0, 0, 11]
#
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [17, 0, 0, 1, 21, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# Episode 11: sum_reward = 91950
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=15, axis1=18)
# DestCoord(axis0=11, axis1=19)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# action = 0, lane = 0
# [116, 0, 0, 31, 0, 5]
#
# action = 0, lane = 0
# [68, 0, 0, 34, 0, 13]
#
# action = 0, lane = 0
# [68, 0, 0, 34, 0, 13]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [14, 0, 0, 0, 9, 5]
#
# action = 0, lane = 0
# [68, 0, 0, 34, 0, 13]
#
# action = 0, lane = 0
# [68, 0, 0, 34, 0, 13]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 5, lane = 1
# [1, 48, 50, 0, 1, 71]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# action = 3, lane = None
# [194, 0, 0, 234, 0, 0]
#
# Episode 12: sum_reward = -33320
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=19)
# DestCoord(axis0=18, axis1=8)
# self.current_lane = 1
# [[G()                  X(0203,5)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 0
# [52, 0, 0, 29, 71, 0]
#
# action = 2, lane = 0
# [2, 2, 108, 1, 2, 17]
#
# action = 3, lane = 2
# [17, 0, 0, 49, 0, 0]
#
# action = 4, lane = 1
# [103, 0, 0, 1, 201, 0]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# action = 2, lane = 0
# [10, 0, 48, 6, 9, 7]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 0, lane = 0
# [3, 3, 0, 0, 2, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 1, lane = 2
# [1, 44, 4, 2, 0, 6]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 10, 2]
#
# action = 4, lane = 0
# [107, 0, 0, 3, 250, 16]
#
# Episode 13: sum_reward = 87105
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=12)
# DestCoord(axis0=13, axis1=23)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 6, 14, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [20, 0, 10, 0, 17, 0]
#
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 2, lane = 0
# [0, 0, 10, 0, 0, 2]
#
# action = 0, lane = 0
# [13, 0, 0, 12, 0, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 4, lane = 0
# [122, 0, 0, 82, 125, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 0, lane = 1
# [19, 0, 1, 2, 0, 0]
#
# action = 0, lane = 1
# [95, 0, 0, 60, 79, 1]
#
# action = 1, lane = 1
# [9, 56, 0, 6, 10, 8]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 14: sum_reward = 92710
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=15)
# DestCoord(axis0=19, axis1=15)
# self.current_lane = 2
# [[G()                  X(0223,7)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 1
# [130, 0, 0, 11, 207, 32]
#
# action = 4, lane = 0
# [16, 0, 19, 0, 20, 5]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 2, lane = 0
# [2, 2, 108, 1, 2, 17]
#
# action = 3, lane = 2
# [17, 0, 0, 49, 0, 0]
#
# action = 4, lane = 1
# [103, 0, 0, 1, 201, 0]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# Episode 15: sum_reward = 76430
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=12, axis1=20)
# DestCoord(axis0=19, axis1=10)
# self.current_lane = 3
# [[R([0, 1]|[0]         X(2203,7)            G()                 ]
#  [G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 2
# [91, 0, 0, 5, 139, 11]
#
# action = 0, lane = 1
# [26, 0, 0, 0, 15, 15]
#
# action = 4, lane = 0
# [91, 0, 0, 5, 139, 11]
#
# action = 3, lane = 1
# [107, 0, 0, 174, 0, 12]
#
# action = 4, lane = 0
# [113, 0, 0, 62, 134, 12]
#
# action = 1, lane = 1
# [2, 107, 6, 0, 0, 17]
#
# action = 0, lane = 1
# [23, 10, 0, 0, 22, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [16, 12, 0, 25, 0, 2]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 2
# [15, 0, 0, 19, 0, 2]
#
# action = 4, lane = 1
# [144, 0, 0, 0, 208, 22]
#
# action = 0, lane = 1
# [31, 0, 0, 15, 29, 6]
#
# action = 0, lane = 1
# [31, 0, 0, 15, 29, 6]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 1, lane = 2
# [2, 51, 3, 2, 1, 4]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [4, 0, 0, 11, 19, 0]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 14, 0]
#
# action = 4, lane = 0
# [107, 0, 0, 3, 250, 16]
#
# action = 3, lane = 2
# [26, 3, 0, 36, 0, 0]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 15, 0]
#
# action = 4, lane = 0
# [85, 0, 0, 4, 202, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 1, lane = 1
# [2, 49, 1, 0, 1, 7]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# Episode 16: sum_reward = 69925
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=17)
# DestCoord(axis0=19, axis1=13)
# self.current_lane = 0
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [52, 0, 0, 29, 71, 0]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 2, lane = 0
# [2, 2, 108, 1, 2, 17]
#
# action = 3, lane = 2
# [17, 0, 0, 49, 0, 0]
#
# action = 4, lane = 1
# [103, 0, 0, 1, 201, 0]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 2
# [7, 2, 0, 24, 0, 1]
#
# Episode 17: sum_reward = 77630
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=11, axis1=13)
# DestCoord(axis0=13, axis1=6)
# self.current_lane = 2
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 1
# [146, 0, 0, 10, 242, 74]
#
# action = 0, lane = 1
# [35, 0, 0, 23, 27, 12]
#
# action = 0, lane = 1
# [35, 0, 0, 23, 27, 12]
#
# action = 5, lane = 1
# [1, 2, 0, 0, 0, 20]
#
# action = 4, lane = 0
# [12, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 1, lane = 2
# [0, 56, 8, 0, 0, 2]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 2, lane = 0
# [15, 0, 38, 0, 14, 6]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# Episode 18: sum_reward = 82220
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=13, axis1=24)
# DestCoord(axis0=10, axis1=20)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [170, 0, 0, 227, 0, 7]
#
# action = 4, lane = 0
# [154, 0, 0, 2, 224, 9]
#
# action = 5, lane = 2
# [1, 3, 3, 2, 0, 33]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# action = 4, lane = 0
# [34, 0, 0, 12, 39, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 2, lane = 0
# [0, 10, 42, 0, 1, 4]
#
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# Episode 19: sum_reward = 81895
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=11, axis1=13)
# DestCoord(axis0=11, axis1=10)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# Episode 20: sum_reward = 105200
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=11, axis1=14)
# DestCoord(axis0=5, axis1=14)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [25, 0, 0, 11, 16, 0]
#
# action = 0, lane = 1
# [25, 0, 0, 11, 16, 0]
#
# action = 1, lane = 3
# [3, 24, 0, 0, 5, 1]
#
# action = 4, lane = 0
# [16, 0, 0, 0, 23, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# action = 1, lane = 1
# [0, 95, 10, 1, 0, 10]
#
# action = 0, lane = 1
# [14, 0, 0, 0, 11, 0]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 0, lane = 0
# [12, 0, 12, 11, 0, 4]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 1, lane = 2
# [0, 37, 1, 0, 1, 27]
#
# action = 1, lane = 1
# [19, 41, 0, 0, 11, 3]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 25, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 1, lane = 3
# [11, 18, 0, 5, 5, 0]
#
# action = 4, lane = 0
# [16, 0, 0, 0, 23, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# Episode 21: sum_reward = 59175
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=11, axis1=15)
# DestCoord(axis0=7, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 4, lane = 0
# [81, 0, 0, 0, 135, 3]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 2, lane = 0
# [2, 8, 77, 2, 0, 9]
#
# action = 3, lane = 1
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 0
# [130, 0, 0, 7, 172, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# action = 2, lane = 0
# [1, 1, 70, 1, 2, 13]
#
# action = 3, lane = 1
# [19, 0, 0, 31, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# Episode 22: sum_reward = 92240
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=15, axis1=13)
# DestCoord(axis0=7, axis1=19)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 1, lane = 1
# [0, 34, 4, 1, 1, 7]
#
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# action = 3, lane = 1
# [100, 0, 0, 181, 0, 0]
#
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# action = 1, lane = 1
# [0, 72, 1, 0, 0, 3]
#
# action = 4, lane = 0
# [12, 0, 0, 0, 22, 0]
#
# Episode 23: sum_reward = 92190
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=17, axis1=12)
# DestCoord(axis0=18, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [87, 0, 0, 7, 166, 32]
#
# action = 3, lane = 1
# [140, 0, 0, 164, 0, 38]
#
# action = 2, lane = 0
# [0, 34, 80, 1, 1, 40]
#
# action = 2, lane = 0
# [16, 0, 22, 19, 0, 3]
#
# action = 3, lane = 2
# [15, 0, 1, 23, 0, 0]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 10, 2]
#
# action = 4, lane = 0
# [107, 0, 0, 3, 250, 16]
#
# Episode 24: sum_reward = 92600
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=15, axis1=18)
# DestCoord(axis0=11, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# action = 0, lane = 0
# [116, 0, 0, 31, 0, 5]
#
# action = 0, lane = 0
# [116, 0, 0, 31, 0, 5]
#
# action = 0, lane = 0
# [116, 0, 0, 31, 0, 5]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 0, lane = 0
# [14, 0, 0, 0, 9, 5]
#
# action = 0, lane = 0
# [68, 0, 0, 34, 0, 13]
#
# action = 0, lane = 0
# [68, 0, 0, 34, 0, 13]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 2, lane = 0
# [2, 8, 77, 2, 0, 9]
#
# action = 3, lane = 1
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 0
# [99, 0, 0, 7, 141, 2]
#
# action = 3, lane = 1
# [8, 0, 0, 16, 0, 3]
#
# action = 4, lane = 0
# [99, 0, 0, 7, 141, 2]
#
# action = 2, lane = 0
# [15, 0, 43, 16, 0, 3]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [18, 4, 0, 23, 0, 0]
#
# Episode 25: sum_reward = 76290
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=10)
# DestCoord(axis0=13, axis1=25)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 1, lane = 2
# [0, 37, 1, 0, 1, 27]
#
# action = 1, lane = 1
# [19, 41, 0, 0, 11, 3]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 25, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 6, 14, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [20, 0, 10, 0, 17, 0]
#
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 2, lane = 0
# [0, 0, 10, 0, 0, 2]
#
# action = 0, lane = 0
# [13, 0, 0, 12, 0, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 4, lane = 0
# [122, 0, 0, 82, 125, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 0, lane = 1
# [21, 0, 0, 1, 0, 6]
#
# action = 0, lane = 1
# [95, 0, 0, 60, 79, 1]
#
# action = 1, lane = 1
# [9, 56, 0, 6, 10, 8]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 26: sum_reward = 80020
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=23, axis1=14)
# DestCoord(axis0=7, axis1=15)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 1, lane = 2
# [1, 82, 52, 0, 1, 8]
#
# action = 4, lane = 0
# [11, 0, 0, 0, 12, 0]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 3, lane = 2
# [5, 0, 4, 9, 7, 5]
#
# action = 4, lane = 1
# [81, 0, 0, 0, 135, 3]
#
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# action = 2, lane = 0
# [2, 2, 81, 1, 0, 13]
#
# action = 3, lane = 2
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 1
# [130, 0, 0, 7, 172, 0]
#
# action = 4, lane = 0
# [57, 0, 0, 37, 81, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [30, 0, 1, 0, 35, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [30, 0, 1, 0, 35, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [99, 0, 0, 7, 141, 2]
#
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# action = 2, lane = 0
# [1, 1, 70, 1, 2, 13]
#
# action = 3, lane = 1
# [19, 0, 0, 31, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 2
# [18, 4, 0, 23, 0, 0]
#
# Episode 27: sum_reward = 70665
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=21, axis1=14)
# DestCoord(axis0=20, axis1=14)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [114, 0, 0, 13, 214, 0]
#
# Episode 28: sum_reward = 90120
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=15, axis1=13)
# DestCoord(axis0=19, axis1=10)
# self.current_lane = 1
# [[R([0, 1, 2]|[2, 1, 0] X(0123,6)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 0, lane = 0
# [3, 3, 0, 0, 2, 0]
#
# action = 0, lane = 0
# [23, 0, 0, 5, 0, 12]
#
# action = 0, lane = 0
# [23, 0, 0, 5, 0, 12]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 1, lane = 2
# [1, 84, 8, 0, 1, 11]
#
# action = 0, lane = 2
# [38, 2, 0, 0, 25, 0]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 15, 0]
#
# action = 4, lane = 0
# [85, 0, 0, 4, 202, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 1, lane = 1
# [2, 49, 1, 0, 1, 7]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# Episode 29: sum_reward = 77170
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=10)
# DestCoord(axis0=17, axis1=8)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 1, lane = 2
# [2, 51, 3, 2, 1, 4]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [4, 0, 0, 11, 19, 0]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 14, 0]
#
# action = 4, lane = 0
# [107, 0, 0, 3, 250, 16]
#
# action = 3, lane = 2
# [15, 1, 0, 23, 0, 1]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 10, 2]
#
# Episode 30: sum_reward = 83835
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=8, axis1=16)
# DestCoord(axis0=11, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [122, 0, 0, 82, 125, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 1, lane = 1
# [0, 67, 17, 0, 1, 6]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# Episode 31: sum_reward = 98935
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=15, axis1=19)
# DestCoord(axis0=19, axis1=19)
# self.current_lane = 1
# [[R([0, 1, 2, 3]|[1, 0] X(2103,6)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0]|[1, 0]         G()                 ]]
# action = 4, lane = 0
# [130, 0, 0, 11, 207, 32]
#
# action = 2, lane = 0
# [0, 4, 32, 0, 1, 5]
#
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# Episode 32: sum_reward = 93370
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=17, axis1=12)
# DestCoord(axis0=11, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# action = 2, lane = 0
# [1, 24, 99, 0, 1, 3]
#
# action = 3, lane = 1
# [12, 0, 0, 21, 0, 1]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 3, lane = 1
# [170, 0, 0, 227, 0, 7]
#
# action = 4, lane = 0
# [154, 0, 0, 2, 224, 9]
#
# action = 3, lane = 1
# [170, 0, 0, 227, 0, 7]
#
# action = 4, lane = 0
# [154, 0, 0, 2, 224, 9]
#
# action = 1, lane = 1
# [1, 73, 9, 0, 0, 10]
#
# action = 0, lane = 1
# [40, 2, 0, 0, 23, 0]
#
# action = 4, lane = 0
# [101, 0, 0, 8, 153, 0]
#
# action = 0, lane = 0
# [12, 0, 0, 7, 0, 5]
#
# action = 3, lane = 1
# [91, 0, 0, 146, 0, 2]
#
# action = 1, lane = 1
# [9, 51, 0, 0, 12, 3]
#
# action = 4, lane = 0
# [9, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# Episode 33: sum_reward = 71305
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=19, axis1=9)
# DestCoord(axis0=19, axis1=16)
# self.current_lane = 1
# [[G()                  X(3020,5)            R([0, 1, 2]|[1, 0]  ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [127, 0, 0, 0, 199, 54]
#
# action = 5, lane = 1
# [0, 0, 21, 0, 0, 39]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [3, 1, 0, 3, 18, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 25, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 34: sum_reward = 94330
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=17)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [130, 0, 0, 11, 207, 32]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# action = 2, lane = 0
# [0, 3, 71, 0, 0, 6]
#
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# action = 4, lane = 1
# [103, 0, 0, 1, 201, 0]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# action = 2, lane = 0
# [10, 0, 48, 6, 9, 7]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# Episode 35: sum_reward = 92850
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=12, axis1=8)
# DestCoord(axis0=15, axis1=10)
# self.current_lane = 1
# [[G()                  X(2023,7)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [92, 0, 0, 4, 151, 7]
#
# action = 3, lane = 1
# [9, 0, 6, 11, 0, 11]
#
# action = 4, lane = 0
# [87, 0, 0, 7, 166, 32]
#
# action = 3, lane = 1
# [140, 0, 0, 164, 0, 38]
#
# action = 4, lane = 0
# [119, 0, 0, 53, 172, 20]
#
# action = 5, lane = 2
# [0, 3, 27, 0, 0, 54]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [5, 2, 0, 19, 32, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 0, lane = 1
# [13, 0, 0, 0, 12, 0]
#
# action = 4, lane = 0
# [85, 0, 0, 4, 202, 0]
#
# action = 1, lane = 1
# [10, 48, 0, 18, 0, 3]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# action = 3, lane = None
# [194, 0, 0, 234, 0, 0]
#
# Episode 36: sum_reward = 52355
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=8, axis1=8)
# DestCoord(axis0=7, axis1=15)
# self.current_lane = 2
# [[G()                  X(0023,5)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [99, 0, 0, 7, 141, 2]
#
# action = 2, lane = 0
# [1, 1, 70, 1, 2, 13]
#
# action = 3, lane = 1
# [19, 0, 0, 31, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 2
# [18, 4, 0, 23, 0, 0]
#
# Episode 37: sum_reward = 83835
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=9, axis1=16)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 2, lane = 0
# [1, 13, 101, 0, 0, 9]
#
# action = 3, lane = 1
# [12, 0, 0, 19, 0, 0]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 3, lane = 1
# [152, 0, 0, 198, 0, 4]
#
# action = 4, lane = 0
# [136, 0, 0, 0, 185, 4]
#
# action = 3, lane = 1
# [152, 0, 0, 198, 0, 4]
#
# action = 4, lane = 0
# [136, 0, 0, 0, 185, 4]
#
# action = 1, lane = 2
# [1, 84, 8, 0, 1, 11]
#
# action = 4, lane = 0
# [5, 2, 0, 19, 32, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 4, lane = 0
# [11, 0, 0, 0, 12, 4]
#
# action = 3, lane = 1
# [111, 0, 0, 141, 0, 1]
#
# action = 1, lane = 1
# [9, 56, 0, 6, 10, 8]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# action = 3, lane = None
# [194, 0, 0, 234, 0, 0]
#
# Episode 38: sum_reward = -39585
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=22, axis1=14)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [101, 0, 0, 8, 153, 0]
#
# action = 3, lane = 1
# [100, 0, 0, 181, 0, 0]
#
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# action = 1, lane = 2
# [0, 95, 10, 1, 0, 10]
#
# action = 0, lane = 2
# [14, 0, 0, 0, 11, 0]
#
# action = 4, lane = 1
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 2
# [5, 0, 4, 9, 7, 5]
#
# action = 4, lane = 1
# [81, 0, 0, 0, 135, 3]
#
# action = 0, lane = 1
# [31, 0, 0, 15, 23, 0]
#
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# action = 2, lane = 0
# [2, 2, 81, 1, 0, 13]
#
# action = 3, lane = 2
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 1
# [130, 0, 0, 7, 172, 0]
#
# action = 4, lane = 0
# [57, 0, 0, 37, 81, 0]
#
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# action = 2, lane = 0
# [23, 0, 37, 0, 13, 4]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [0, 0, 0, 0, 67, 0]
#
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# Episode 39: sum_reward = 86495
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=6, axis1=14)
# DestCoord(axis0=11, axis1=9)
# self.current_lane = 1
# [[R([0, 1, 2]|[1, 0]   X(4320,9)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 2, lane = 0
# [1, 13, 101, 0, 0, 9]
#
# action = 3, lane = 2
# [12, 0, 0, 19, 0, 0]
#
# action = 4, lane = 1
# [160, 0, 0, 0, 201, 0]
#
# action = 0, lane = 1
# [39, 0, 0, 14, 29, 0]
#
# action = 0, lane = 1
# [39, 0, 0, 14, 29, 0]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 1, lane = 2
# [2, 51, 3, 2, 1, 4]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [122, 0, 0, 82, 125, 0]
#
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# action = 1, lane = 1
# [9, 56, 0, 6, 10, 8]
#
# action = 4, lane = 0
# [23, 1, 0, 0, 33, 0]
#
# Episode 40: sum_reward = 87225
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=10)
# DestCoord(axis0=13, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 1, lane = 2
# [2, 51, 3, 2, 1, 4]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 13, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 2, lane = 0
# [15, 0, 38, 0, 14, 6]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# Episode 41: sum_reward = 92670
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=19, axis1=16)
# DestCoord(axis0=9, axis1=16)
# self.current_lane = 1
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 196, 2]
#
# action = 3, lane = 1
# [170, 0, 0, 184, 0, 2]
#
# action = 1, lane = 3
# [1, 53, 3, 1, 1, 4]
#
# action = 0, lane = 3
# [20, 0, 0, 0, 20, 0]
#
# action = 4, lane = 2
# [101, 0, 0, 8, 153, 0]
#
# action = 0, lane = 2
# [106, 0, 0, 61, 98, 0]
#
# action = 4, lane = 1
# [101, 0, 0, 8, 153, 0]
#
# action = 0, lane = 1
# [40, 2, 0, 0, 23, 0]
#
# action = 4, lane = 0
# [101, 0, 0, 8, 153, 0]
#
# action = 0, lane = 0
# [15, 0, 0, 9, 0, 0]
#
# action = 3, lane = 1
# [100, 0, 0, 181, 0, 0]
#
# action = 0, lane = 1
# [40, 2, 0, 0, 23, 0]
#
# action = 4, lane = 0
# [78, 0, 0, 6, 117, 2]
#
# action = 3, lane = 1
# [91, 0, 0, 146, 0, 2]
#
# action = 4, lane = 0
# [99, 0, 0, 52, 100, 3]
#
# action = 1, lane = 1
# [2, 107, 6, 0, 0, 17]
#
# action = 0, lane = 1
# [23, 10, 0, 0, 22, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 1, lane = 2
# [18, 19, 0, 12, 0, 1]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 18, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# Episode 42: sum_reward = 70575
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=13, axis1=22)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [195, 0, 0, 213, 0, 82]
#
# action = 4, lane = 0
# [146, 0, 0, 10, 242, 74]
#
# action = 3, lane = 1
# [195, 0, 0, 213, 0, 82]
#
# action = 4, lane = 0
# [146, 0, 0, 10, 242, 74]
#
# action = 5, lane = 2
# [1, 11, 8, 0, 3, 126]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [58, 0, 0, 27, 61, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 1, lane = 2
# [0, 36, 34, 1, 0, 1]
#
# action = 4, lane = 0
# [13, 1, 0, 8, 17, 9]
#
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# action = 2, lane = 0
# [10, 0, 48, 6, 9, 7]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# Episode 43: sum_reward = 74580
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=15)
# DestCoord(axis0=16, axis1=20)
# self.current_lane = 2
# [[G()                  X(0223,7)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 1
# [118, 0, 0, 15, 203, 0]
#
# action = 0, lane = 1
# [20, 0, 10, 0, 17, 0]
#
# action = 4, lane = 0
# [130, 0, 0, 11, 207, 32]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# action = 2, lane = 0
# [0, 3, 71, 0, 0, 6]
#
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [7, 0, 1, 7, 8, 0]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [4, 0, 0, 11, 19, 0]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [7, 0, 1, 7, 8, 0]
#
# Episode 44: sum_reward = 99555
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=16, axis1=12)
# DestCoord(axis0=11, axis1=9)
# self.current_lane = 0
# ...
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 2, lane = 0
# [2, 8, 77, 2, 0, 9]
#
# action = 3, lane = 1
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 0
# [130, 0, 0, 7, 172, 0]
#
# action = 3, lane = 1
# [7, 2, 0, 16, 0, 0]
#
# action = 4, lane = 0
# [130, 0, 0, 7, 172, 0]
#
# action = 2, lane = 0
# [15, 0, 43, 16, 0, 3]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 4, lane = 0
# [15, 4, 0, 0, 18, 0]
#
# action = 3, lane = None
# [167, 0, 0, 176, 0, 0]
#
# Episode 985: sum_reward = -32480
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=19, axis1=16)
# DestCoord(axis0=11, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 0, lane = 1
# [12, 0, 0, 3, 8, 0]
#
# action = 0, lane = 1
# [31, 0, 0, 15, 23, 0]
#
# action = 3, lane = 2
# [5, 0, 4, 9, 7, 5]
#
# action = 4, lane = 1
# [81, 0, 0, 0, 135, 3]
#
# action = 0, lane = 1
# [31, 0, 0, 15, 23, 0]
#
# action = 4, lane = 0
# [81, 0, 0, 0, 135, 3]
#
# action = 2, lane = 0
# [2, 2, 81, 1, 0, 13]
#
# action = 3, lane = 2
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 1
# [130, 0, 0, 7, 172, 0]
#
# action = 4, lane = 0
# [57, 0, 0, 37, 81, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [30, 0, 1, 0, 35, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# action = 2, lane = 0
# [23, 0, 37, 0, 13, 4]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 986: sum_reward = 92050
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=11, axis1=19)
# DestCoord(axis0=4, axis1=14)
# self.current_lane = 0
# [[R([0, 1, 2]|[1, 0]   X(2203,7)            R([0, 1, 2]|[3, 2, 1, 0]]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# action = 0, lane = 0
# [35, 0, 0, 0, 0, 0]
#
# action = 1, lane = 1
# [1, 73, 9, 0, 0, 10]
#
# action = 0, lane = 1
# [40, 2, 0, 0, 23, 0]
#
# action = 4, lane = 0
# [101, 0, 0, 8, 153, 0]
#
# action = 3, lane = 1
# [100, 0, 0, 181, 0, 0]
#
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# action = 1, lane = 1
# [0, 7, 0, 0, 0, 1]
#
# action = 0, lane = 1
# [14, 0, 0, 0, 11, 0]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 3, lane = 1
# [10, 0, 1, 14, 0, 0]
#
# action = 4, lane = 0
# [81, 0, 0, 0, 135, 3]
#
# action = 0, lane = 0
# [12, 0, 12, 11, 0, 4]
#
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# action = 1, lane = 2
# [0, 3, 0, 0, 0, 3]
#
# action = 5, lane = None
# [10, 2, 0, 0, 11, 12]
#
# action = 2, lane = 0
# [0, 0, 8, 0, 0, 0]
#
# action = 3, lane = 1
# [12, 0, 0, 21, 0, 1]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [25, 0, 0, 11, 16, 0]
#
# action = 1, lane = 3
# [11, 18, 0, 5, 5, 0]
#
# action = 4, lane = 0
# [16, 0, 0, 0, 23, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# Episode 987: sum_reward = 62705
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=10, axis1=20)
# DestCoord(axis0=16, axis1=20)
# self.current_lane = 1
# [[G()                  X(2203,7)            R([0]|[1, 0]        ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [4, 0, 0, 11, 19, 0]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [7, 0, 1, 7, 8, 0]
#
# Episode 988: sum_reward = 105400
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=12, axis1=20)
# DestCoord(axis0=16, axis1=20)
# self.current_lane = 2
# [[R([0, 1]|[0]         X(2203,7)            G()                 ]
#  [G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [119, 0, 0, 53, 172, 20]
#
# action = 5, lane = 2
# [0, 0, 0, 0, 1, 18]
#
# action = 0, lane = 2
# [25, 0, 0, 0, 14, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [4, 0, 0, 11, 19, 0]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [7, 0, 1, 7, 8, 0]
#
# Episode 989: sum_reward = 95080
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=13, axis1=22)
# DestCoord(axis0=18, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 1, lane = 2
# [0, 56, 8, 0, 0, 2]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 2, lane = 0
# [10, 0, 48, 6, 9, 7]
#
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 0, lane = 0
# [43, 0, 0, 8, 0, 0]
#
# action = 3, lane = 1
# [163, 0, 0, 212, 0, 0]
#
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 1, lane = 2
# [0, 18, 0, 0, 0, 0]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 18, 0]
#
# action = 4, lane = 1
# [0, 0, 0, 0, 10, 2]
#
# action = 4, lane = 0
# [107, 0, 0, 3, 250, 16]
#
# Episode 990: sum_reward = 86565
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=11, axis1=19)
# self.current_lane = 1
# [[R([0]|[1, 0]         X(2103,6)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [62, 0, 0, 54, 107, 0]
#
# action = 3, lane = 1
# [18, 2, 0, 20, 0, 0]
#
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# action = 0, lane = 0
# [15, 0, 0, 9, 0, 0]
#
# action = 3, lane = 1
# [100, 0, 0, 181, 0, 0]
#
# action = 1, lane = 1
# [9, 51, 0, 0, 12, 3]
#
# action = 4, lane = 0
# [9, 0, 0, 0, 15, 0]
#
# Episode 991: sum_reward = 99855
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=4, axis1=14)
# DestCoord(axis0=19, axis1=13)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 1, lane = 1
# [0, 98, 37, 0, 1, 8]
#
# action = 0, lane = 1
# [19, 0, 0, 4, 13, 0]
#
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# action = 2, lane = 0
# [16, 0, 22, 19, 0, 3]
#
# action = 3, lane = 2
# [15, 0, 1, 23, 0, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 1, lane = 1
# [0, 98, 37, 0, 1, 8]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 0, lane = 0
# [185, 0, 0, 178, 0, 17]
#
# action = 0, lane = 0
# [46, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [46, 0, 0, 0, 0, 0]
#
# action = 2, lane = 0
# [1, 8, 61, 1, 1, 4]
#
# action = 3, lane = 2
# [17, 0, 0, 49, 0, 0]
#
# action = 4, lane = 1
# [103, 0, 0, 1, 201, 0]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 2
# [7, 2, 0, 24, 0, 1]
#
# Episode 992: sum_reward = 58355
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=21, axis1=14)
# DestCoord(axis0=13, axis1=23)
# self.current_lane = 2
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [76, 0, 0, 3, 172, 7]
#
# action = 0, lane = 1
# [93, 0, 0, 70, 83, 6]
#
# action = 0, lane = 1
# [93, 0, 0, 70, 83, 6]
#
# action = 5, lane = 1
# [0, 6, 1, 0, 0, 73]
#
# action = 4, lane = 0
# [130, 0, 0, 7, 172, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [130, 0, 0, 7, 172, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [57, 0, 0, 37, 81, 0]
#
# action = 2, lane = 0
# [1, 24, 99, 0, 1, 3]
#
# action = 3, lane = 1
# [12, 0, 0, 21, 0, 1]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# action = 1, lane = 3
# [0, 8, 1, 0, 0, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [57, 0, 0, 37, 81, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 175, 0, 0]
#
# action = 4, lane = 0
# [10, 0, 0, 0, 15, 0]
#
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# action = 2, lane = 0
# [5, 0, 17, 0, 6, 2]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# Episode 993: sum_reward = 70615
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=19)
# DestCoord(axis0=19, axis1=18)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# action = 1, lane = 2
# [8, 26, 0, 0, 14, 2]
#
# action = 0, lane = 2
# [20, 1, 0, 0, 18, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 1, lane = 1
# [0, 98, 37, 0, 1, 8]
#
# action = 4, lane = 0
# [15, 0, 0, 0, 21, 0]
#
# action = 3, lane = None
# [151, 0, 0, 216, 0, 31]
#
# Episode 994: sum_reward = -33130
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=11)
# DestCoord(axis0=5, axis1=14)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# action = 1, lane = 3
# [11, 18, 0, 5, 5, 0]
#
# action = 4, lane = 0
# [16, 0, 0, 0, 23, 0]
#
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# Episode 995: sum_reward = 84675
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=11, axis1=19)
# DestCoord(axis0=10, axis1=8)
# self.current_lane = 1
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0]|[1, 0]         G()                 ]]
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [9, 0, 0, 18, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# action = 2, lane = 0
# [0, 10, 42, 0, 1, 4]
#
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# Episode 996: sum_reward = 100095
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=7, axis1=10)
# DestCoord(axis0=7, axis1=18)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 0, lane = 0
# [174, 0, 0, 170, 0, 62]
#
# action = 1, lane = 2
# [0, 37, 1, 0, 1, 27]
#
# action = 1, lane = 1
# [19, 41, 0, 0, 11, 3]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 25, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# action = 4, lane = 0
# [36, 0, 0, 18, 41, 0]
#
# action = 3, lane = 2
# [18, 4, 0, 23, 0, 0]
#
# action = 4, lane = 1
# [138, 0, 0, 3, 267, 0]
#
# action = 0, lane = 1
# [25, 0, 0, 0, 25, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 997: sum_reward = 92840
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=7, axis1=10)
# DestCoord(axis0=19, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# action = 0, lane = 0
# [18, 0, 0, 18, 0, 0]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [16, 0, 19, 0, 20, 5]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# action = 3, lane = 1
# [151, 0, 0, 216, 0, 31]
#
# action = 2, lane = 0
# [0, 3, 71, 0, 0, 6]
#
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# action = 4, lane = 0
# [7, 0, 1, 7, 8, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# Episode 998: sum_reward = 91320
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 2
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [84, 0, 0, 0, 149, 2]
#
# action = 0, lane = 1
# [114, 0, 0, 75, 111, 7]
#
# action = 2, lane = 0
# [1, 5, 77, 0, 0, 37]
#
# action = 0, lane = 0
# [26, 0, 4, 0, 0, 0]
#
# action = 0, lane = 0
# [133, 0, 0, 25, 0, 0]
#
# action = 0, lane = 0
# [133, 0, 0, 25, 0, 0]
#
# action = 0, lane = 0
# [133, 0, 0, 25, 0, 0]
#
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# action = 4, lane = 0
# [81, 0, 0, 0, 135, 3]
#
# action = 3, lane = 2
# [11, 0, 0, 12, 0, 0]
#
# action = 4, lane = 1
# [81, 0, 0, 0, 135, 3]
#
# action = 0, lane = 1
# [6, 0, 6, 6, 2, 3]
#
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# action = 2, lane = 0
# [2, 2, 81, 1, 0, 13]
#
# action = 3, lane = 2
# [27, 0, 1, 37, 0, 1]
#
# action = 4, lane = 1
# [130, 0, 0, 7, 172, 0]
#
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# action = 2, lane = 0
# [23, 0, 37, 0, 13, 4]
#
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# action = 4, lane = 0
# [0, 0, 0, 0, 67, 0]
#
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# action = 3, lane = 1
# [19, 0, 0, 31, 0, 0]
#
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 999: sum_reward = 85015
#
#
# 882/1000 objects reached their destination. Where next_to_border = 440
