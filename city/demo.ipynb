# %%
from Agent.agent import Agent

# %%
agent = Agent(5, 0)
# Out:
# Empty city was built.
# Ground was built.
# Intersections were built.
# Roads were built.
# Intersections were finalized.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [00:57<00:00,  1.70it/s]
# Transition dictionary was built.
# sys.getsizeof(self.states) = 732808
# sys.getsizeof(self.P) = 5242968

# %%
agent.extract_q_table(Agent.load_compressed_q_table_from_file('compressed_q_table'))
# Out:
# Q_table extraction progress: 100%|█████████████████████████████████████████████| 89012/89012 [00:20<00:00, 4346.05it/s]

# %%
agent.perform(10)
# Out:
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 1
# [[G()                  X(4023,9)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 1
# [[G()                  X(4023,9)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [87, 0, 0, 7, 166, 32]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]
#  [G()                  X(4023,9)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 5, lane = 2
# [1, 0, 3, 1, 0, 14]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 2
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(4023,9)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [4, 0, 0, 11, 19, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 0
# [[G()                  X(2103,6)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(2103,6)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [7, 0, 1, 7, 8, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=18, axis1=20)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# Episode 0: sum_reward = 94240
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=13, axis1=24)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 2
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=13, axis1=24)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 2
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [133, 0, 0, 0, 287, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=13, axis1=23)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [58, 0, 0, 27, 61, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=13, axis1=22)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=13, axis1=21)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 1
# [[R([0, 1]|[3, 2, 1, 0] X(4023,9)            R([0, 1, 2, 3]|[2, 1, 0]]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[3, 2, 1, 0] X(4023,9)            R([0, 1, 2, 3]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 1, lane = 2
# [0, 36, 34, 1, 0, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 2
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(4023,9)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [13, 1, 0, 8, 17, 9]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  X(2103,6)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(2103,6)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [10, 0, 48, 6, 9, 7]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(2103,6)            R([0, 1]|[3, 2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=19)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=18)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=17)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=16)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=15)
# DestCoord(axis0=15, axis1=14)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# Episode 1: sum_reward = 76940
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  X(4023,9)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  X(4023,9)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [107, 0, 0, 174, 0, 12]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]
#  [G()                  X(4023,9)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 5, lane = 2
# [3, 0, 0, 4, 0, 11]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 2
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(4023,9)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  X(2103,6)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(2103,6)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=18, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  X(4100,5)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [G()                  X(4100,5)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  X(4100,5)            R([0, 1, 2, 3]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=19)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=18)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=17)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=16)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=15)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[R([0, 1, 2]|[2, 1, 0] X(0323,8)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=14)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0323,8)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 2
# [7, 2, 0, 24, 0, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=13)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 2
# [[G()                  X(2320,7)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [133, 0, 0, 0, 287, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=12)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  X(2320,7)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [1, 0, 0, 2, 8, 0]
#
# Episode 2: sum_reward = 87295
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=8, axis1=16)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=8, axis1=16)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=9, axis1=16)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=10, axis1=16)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[R([0, 1]|[1, 0]      X(4220,8)            R([0, 1, 2]|[1, 0]  ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=11, axis1=16)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[1, 0]      X(4220,8)            R([0, 1, 2]|[1, 0]  ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [1, 13, 101, 0, 0, 9]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=16)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  X(4220,8)            R([0, 1, 2, 3]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [12, 0, 0, 19, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=15)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [160, 0, 0, 0, 201, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=14)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=13)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=12)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=11)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [144, 0, 0, 0, 208, 22]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=10)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [171, 0, 0, 211, 0, 18]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=9)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[R([0, 1]|[3, 2, 1, 0] X(2023,7)            R([0, 1]|[3, 2, 1, 0]]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [136, 0, 0, 0, 185, 4]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=11, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[3, 2, 1, 0] X(2023,7)            R([0, 1]|[3, 2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 1, lane = 2
# [1, 84, 8, 0, 1, 11]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=11, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 2
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(2023,7)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [5, 2, 0, 19, 32, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=12, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  X(2103,6)            R([0]|[0]           ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [118, 0, 0, 172, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=13, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  X(2103,6)            R([0]|[0]           ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [13, 0, 0, 0, 12, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=14, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[R([0, 1]|[1, 0]      X(2023,7)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [85, 0, 0, 4, 202, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=15, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(2023,7)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 2
# [26, 3, 0, 36, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=16, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [0, 0, 0, 0, 36, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=17, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [77, 0, 0, 4, 133, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=18, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[R([0, 1]|[1, 0]      X(3020,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [111, 0, 0, 141, 0, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=19, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[1, 0]      X(3020,5)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 1, lane = 1
# [3, 78, 2, 0, 0, 16]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=8)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(3020,5)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [15, 4, 0, 0, 18, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=9)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=10)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=11)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[R([0, 1]|[1, 0]      X(2320,7)            G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=12)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(2320,7)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 1, lane = 1
# [11, 18, 0, 5, 5, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=19, axis1=12)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [R([0, 1, 2]|[1, 0]   X(2320,7)            R([0, 1, 2]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [16, 0, 0, 0, 23, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=18, axis1=12)
# DestCoord(axis0=17, axis1=12)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# Episode 3: sum_reward = 65470
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [114, 0, 0, 75, 111, 7]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=18, axis1=20)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  X(4100,5)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [114, 0, 0, 75, 111, 7]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [G()                  X(4100,5)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [1, 5, 77, 0, 0, 37]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  X(4100,5)            R([0, 1, 2, 3]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [26, 0, 4, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=19)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [133, 0, 0, 25, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=18)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [116, 0, 0, 31, 0, 5]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=17)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [116, 0, 0, 31, 0, 5]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=16)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [116, 0, 0, 123, 0, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=15)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[R([0, 1, 2]|[2, 1, 0] X(0323,8)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=14)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0323,8)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 2
# [3, 1, 0, 11, 0, 3]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=13)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 2
# [[G()                  X(2320,7)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [97, 0, 0, 0, 160, 13]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=12)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  X(2320,7)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [6, 0, 6, 6, 2, 3]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=11)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=10)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [37, 0, 0, 13, 35, 5]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=9)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  X(3020,5)            R([0, 1, 2]|[1, 0]  ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [97, 0, 0, 0, 160, 13]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(3020,5)            R([0, 1, 2]|[1, 0]  ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [2, 2, 81, 1, 0, 13]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=19, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  X(3020,5)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 2
# [27, 0, 1, 37, 0, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=18, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 2
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [99, 0, 0, 7, 141, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=17, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=16, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  X(2023,7)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=15, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  X(2023,7)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [23, 0, 37, 0, 13, 4]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=8)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [R([0, 1]|[1, 0]      X(2023,7)            R([0, 1, 2]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=9)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0]|[0]            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [0, 0, 0, 0, 67, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=10)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0]|[0]            G()                 ]
#  [G()                  R([0]|[0]            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=11)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  X(0123,6)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0]|[0]            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [101, 0, 0, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=12)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  X(0123,6)            R([0, 1, 2]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [19, 0, 0, 31, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=13)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=14)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=15)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 1
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=15, axis1=16)
# DestCoord(axis0=15, axis1=17)
# self.current_lane = 0
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0]|[1, 0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [194, 0, 0, 234, 0, 0]
#
# Episode 4: sum_reward = 68605
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [99, 0, 0, 52, 100, 3]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 1
# [[R([0]|[1, 0]         X(2103,6)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [99, 0, 0, 52, 100, 3]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [R([0]|[1, 0]         X(2103,6)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 1, lane = 0
# [15, 37, 0, 17, 0, 6]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(2103,6)            R([0, 1]|[3, 2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [29, 1, 0, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=19)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=18)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=17)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=16)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=15, axis1=15)
# DestCoord(axis0=15, axis1=11)
# self.current_lane = 0
# ...
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(4023,9)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [6, 0, 0, 18, 20, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  X(2103,6)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(2103,6)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [12, 0, 0, 14, 17, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [107, 0, 0, 130, 0, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=18, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  X(4100,5)            R([0, 1]|[0]        ]
#  [G()                  R([0, 1, 2, 3]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 1
# [105, 0, 0, 60, 90, 2]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'S'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [G()                  X(4100,5)            R([0, 1]|[0]        ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  X(4100,5)            R([0, 1, 2, 3]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [21, 0, 0, 0, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=19)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=18)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[0]         G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=17)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 0
# [109, 0, 0, 23, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=16)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=15)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[R([0, 1, 2]|[2, 1, 0] X(0323,8)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=14)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0323,8)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 2
# [7, 2, 0, 24, 0, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=13)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 2
# [[G()                  X(2320,7)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [133, 0, 0, 0, 287, 1]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'W'
# CarCoord(axis0=19, axis1=12)
# DestCoord(axis0=19, axis1=11)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  X(2320,7)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [1, 0, 0, 2, 8, 0]
#
# Episode 8: sum_reward = 98535
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=19, axis1=10)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=10)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=11)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[R([0, 1]|[1, 0]      X(2320,7)            G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=12)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(2320,7)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 2
# [6, 6, 0, 9, 6, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=13)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 2
# [[G()                  X(0323,8)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [123, 0, 0, 2, 189, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=14)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  X(0323,8)            R([0, 1, 2]|[2, 1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [15, 0, 0, 0, 19, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=15)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=16)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=17)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0]|[1, 0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=18)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0]|[1, 0]         G()                 ]
#  [G()                  R([0]|[1, 0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=19)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[R([0, 1, 2]|[3, 2, 1, 0] X(4100,5)            G()                 ]
#  [G()                  R([0]|[1, 0]         G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1, 2]|[3, 2, 1, 0] X(4100,5)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 1, lane = 3
# [1, 53, 3, 1, 1, 4]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=19, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 3
# [[G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]
#  [R([0]|[1, 0]         X(4100,5)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 0, lane = 3
# [20, 0, 0, 0, 20, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=18, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 3
# [[G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 2
# [114, 0, 0, 13, 214, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=17, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 1
# [57, 0, 0, 37, 81, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=16, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[R([0]|[1, 0]         X(2103,6)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [57, 0, 0, 37, 81, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=15, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [R([0]|[1, 0]         X(2103,6)            G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [7, 2, 0, 16, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=14, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  X(4023,9)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [130, 0, 0, 7, 172, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'N'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[3, 2, 1, 0] G()                 ]
#  [G()                  X(4023,9)            R([0, 1]|[1, 0]     ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 2, lane = 0
# [15, 0, 43, 16, 0, 3]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=13, axis1=20)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [R([0, 1, 2]|[3, 2, 1, 0] X(4023,9)            R([0, 1, 2, 3]|[1, 0]]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 3, lane = 1
# [22, 0, 0, 35, 0, 0]
#
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  \\\\\\
# self.current_direction = 'E'
# CarCoord(axis0=13, axis1=21)
# DestCoord(axis0=13, axis1=22)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# ВЫВОД ДЛЯ ГРАФИКИ!!! -----------------------------------------  //////
# action = 4, lane = 0
# [138, 0, 0, 3, 267, 0]
#
# Episode 9: sum_reward = 94270
#
#
# 10/10 objects reached their destination. Where next_to_border = 6
