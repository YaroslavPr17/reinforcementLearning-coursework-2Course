# %%
from Agent.agent import Agent

# %%
agent = Agent(1, 0)
# Out:
# Empty city was built.
# Ground was built.
# Intersections were built.
# Roads were built.
# Intersections were finalized.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 26/26 [00:04<00:00,  6.10it/s]
# Transition dictionary was built.
# sys.getsizeof(self.states) = 54560
# sys.getsizeof(self.P) = 295000

# %%
agent.extract_q_table(Agent.load_compressed_q_table_from_file('compressed_q_table'))
# Out:
# Q_table extraction progress: 100%|███████████████████████████████████████████████| 6776/6776 [00:01<00:00, 4528.54it/s]
# ButtonPress:  144 497
# ButtonRelease:  887 521
# ButtonPress:  311 595
# ButtonRelease:  530 453
# ButtonPress:  408 538
# ButtonRelease:  605 654
# ButtonPress:  415 562
# ButtonRelease:  545 644
# Scale:  2.100000000000001
# Scale:  2.100000000000001
# Scale:  2.200000000000001
# Scale:  2.300000000000001
# Scale:  2.300000000000001
# Scale:  2.4000000000000012
# Scale:  2.5000000000000013

# %%
agent.perform(10)
# Out:
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# self.current_direction = 'S'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [114, 0, 0, 75, 111, 7]
#
# self.current_direction = 'S'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [114, 0, 0, 75, 111, 7]
#
# self.current_direction = 'S'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 72, 115, 27]
#
# self.current_direction = 'S'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 0
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [139, 0, 0, 144, 0, 29]
#
# self.current_direction = 'S'
# CarCoord(axis0=6, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 72, 115, 27]
#
# self.current_direction = 'S'
# CarCoord(axis0=7, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 0
# [[G()                  X(2200,4)            R([0, 1, 2]|[1, 0]  ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [139, 0, 0, 144, 0, 29]
#
# self.current_direction = 'S'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [G()                  X(2200,4)            R([0, 1, 2]|[1, 0]  ]]
# action = 5, lane = 1
# [0, 1, 26, 0, 1, 56]
#
# self.current_direction = 'N'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(2200,4)            G()                 ]]
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=7, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=6, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]]
# action = 1, lane = 1
# [0, 72, 1, 0, 0, 3]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=1, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0203,5)            G()                 ]]
# action = 4, lane = 0
# [12, 0, 0, 0, 22, 0]
#
# Episode 0: sum_reward = 86805
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 2
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 2
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [87, 0, 0, 7, 166, 32]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]]
# action = 1, lane = 1
# [0, 40, 1, 0, 0, 39]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0203,5)            G()                 ]]
# action = 1, lane = 2
# [8, 26, 0, 0, 14, 2]
#
# self.current_direction = 'S'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(0203,5)            R([0, 1, 2]|[1, 0]  ]]
# action = 0, lane = 2
# [25, 0, 0, 0, 14, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# self.current_direction = 'S'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# self.current_direction = 'S'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 0
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# self.current_direction = 'S'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 1
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# self.current_direction = 'S'
# CarCoord(axis0=6, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 0
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [132, 0, 0, 161, 0, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=7, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 1
# [[G()                  X(2200,4)            R([0, 1, 2]|[1, 0]  ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [112, 0, 0, 78, 120, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(2200,4)            R([0, 1, 2]|[1, 0]  ]]
# action = 2, lane = 0
# [0, 2, 70, 0, 0, 12]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=8, axis1=6)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  X(2200,4)            R([0, 1]|[3, 2, 1, 0]]]
# action = 3, lane = 1
# [9, 0, 0, 18, 0, 0]
#
# Episode 1: sum_reward = 72635
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# self.current_direction = 'N'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [87, 0, 0, 7, 166, 32]
#
# self.current_direction = 'N'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [140, 0, 0, 164, 0, 38]
#
# self.current_direction = 'N'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [119, 0, 0, 53, 172, 20]
#
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [140, 0, 0, 164, 0, 38]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]]
# action = 1, lane = 1
# [0, 40, 1, 0, 0, 39]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0203,5)            G()                 ]]
# action = 1, lane = 2
# [8, 26, 0, 0, 14, 2]
#
# self.current_direction = 'S'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(0203,5)            R([0, 1, 2]|[1, 0]  ]]
# action = 0, lane = 2
# [25, 0, 0, 0, 14, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# self.current_direction = 'S'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# self.current_direction = 'S'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# Episode 2: sum_reward = 77170
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=1, axis1=4)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=4)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [136, 0, 0, 0, 185, 4]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=3)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [152, 0, 0, 198, 0, 4]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=2)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[R([0, 1, 2]|[2, 1, 0] X(0023,5)            G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [136, 0, 0, 0, 185, 4]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0023,5)            G()                 ]]
# action = 1, lane = 2
# [0, 75, 1, 1, 2, 11]
#
# self.current_direction = 'S'
# CarCoord(axis0=1, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [R([0, 1]|[1, 0]      X(0023,5)            G()                 ]]
# action = 0, lane = 2
# [38, 2, 0, 0, 25, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=2, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [77, 0, 0, 4, 133, 1]
#
# self.current_direction = 'S'
# CarCoord(axis0=3, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [95, 0, 0, 60, 79, 1]
#
# self.current_direction = 'S'
# CarCoord(axis0=4, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [95, 0, 0, 60, 79, 1]
#
# self.current_direction = 'S'
# CarCoord(axis0=5, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [95, 0, 0, 60, 79, 1]
#
# self.current_direction = 'S'
# CarCoord(axis0=6, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [95, 0, 0, 60, 79, 1]
#
# self.current_direction = 'S'
# CarCoord(axis0=7, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[R([0, 1]|[1, 0]      X(4020,6)            G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [93, 0, 0, 70, 83, 6]
#
# self.current_direction = 'S'
# CarCoord(axis0=8, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[1, 0]      X(4020,6)            G()                 ]]
# action = 1, lane = 1
# [3, 78, 2, 0, 0, 16]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=1)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [R([0, 1, 2, 3]|[3, 2, 1, 0] X(4020,6)            G()                 ]]
# action = 4, lane = 0
# [15, 4, 0, 0, 18, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=2)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=3)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [123, 0, 0, 2, 189, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=4)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 3, lane = 1
# [167, 0, 0, 176, 0, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=5)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [29, 0, 0, 9, 18, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=6)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[R([0, 1, 2, 3]|[1, 0] X(2200,4)            G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [25, 0, 0, 11, 16, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1, 2, 3]|[1, 0] X(2200,4)            G()                 ]]
# action = 1, lane = 1
# [1, 53, 3, 1, 1, 4]
#
# self.current_direction = 'N'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(2200,4)            G()                 ]]
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=7, axis1=7)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=6, axis1=7)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 3, lane = 1
# [129, 0, 0, 183, 0, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=4, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# Episode 3: sum_reward = 84495
#
#
# INITIAL STATE:
#  self.current_direction = 'W'
# CarCoord(axis0=8, axis1=6)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=6)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [81, 0, 0, 0, 135, 3]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=5)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=4)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=3)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=2)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  X(4020,6)            R([0, 1, 2, 3]|[3, 2, 1, 0]]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 0, lane = 0
# [156, 0, 0, 137, 0, 11]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(4020,6)            R([0, 1, 2, 3]|[3, 2, 1, 0]]]
# action = 2, lane = 0
# [2, 2, 81, 1, 0, 13]
#
# self.current_direction = 'N'
# CarCoord(axis0=8, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  X(4020,6)            R([0, 1]|[1, 0]     ]]
# action = 3, lane = 3
# [27, 0, 1, 37, 0, 1]
#
# self.current_direction = 'N'
# CarCoord(axis0=7, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 3
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 2
# [99, 0, 0, 7, 141, 2]
#
# self.current_direction = 'N'
# CarCoord(axis0=6, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 0, lane = 2
# [55, 0, 0, 39, 51, 4]
#
# self.current_direction = 'N'
# CarCoord(axis0=5, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 0, lane = 2
# [55, 0, 0, 39, 51, 4]
#
# self.current_direction = 'N'
# CarCoord(axis0=4, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [99, 0, 0, 7, 141, 2]
#
# self.current_direction = 'N'
# CarCoord(axis0=3, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  X(0023,5)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [87, 0, 0, 46, 108, 10]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(0023,5)            R([0, 1]|[1, 0]     ]]
# action = 2, lane = 0
# [2, 1, 76, 0, 1, 40]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  X(0023,5)            R([0, 1, 2]|[2, 1, 0]]]
# action = 3, lane = 1
# [13, 0, 10, 23, 0, 1]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=2)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=3)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=4)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=5)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=6)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  X(0203,5)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(0203,5)            R([0, 1, 2]|[2, 1, 0]]]
# action = 2, lane = 0
# [0, 3, 71, 0, 0, 6]
#
# self.current_direction = 'S'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(0203,5)            R([0, 1, 2]|[1, 0]  ]]
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# self.current_direction = 'S'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# self.current_direction = 'S'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# Episode 4: sum_reward = 71425
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 2
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 2
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [78, 0, 0, 6, 117, 2]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]]
# action = 1, lane = 1
# [0, 72, 1, 0, 0, 3]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0203,5)            G()                 ]]
# action = 4, lane = 0
# [12, 0, 0, 0, 22, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=6)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=5)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# Episode 5: sum_reward = 98835
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# self.current_direction = 'N'
# CarCoord(axis0=5, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [101, 0, 0, 8, 153, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [100, 0, 0, 181, 0, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [106, 0, 0, 61, 98, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [99, 0, 0, 52, 100, 3]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(0203,5)            G()                 ]]
# action = 1, lane = 1
# [0, 72, 1, 0, 0, 3]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [R([0, 1, 2]|[2, 1, 0] X(0203,5)            G()                 ]]
# action = 4, lane = 0
# [12, 0, 0, 0, 22, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=6)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=1, axis1=5)
# DestCoord(axis0=1, axis1=4)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# Episode 6: sum_reward = 98925
#
#
# INITIAL STATE:
#  self.current_direction = 'N'
# CarCoord(axis0=5, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# self.current_direction = 'N'
# CarCoord(axis0=5, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [109, 0, 0, 142, 0, 2]
#
# self.current_direction = 'N'
# CarCoord(axis0=4, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# self.current_direction = 'N'
# CarCoord(axis0=3, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 0, lane = 1
# [55, 0, 0, 39, 51, 4]
#
# self.current_direction = 'N'
# CarCoord(axis0=2, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  X(0023,5)            R([0, 1]|[1, 0]     ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [87, 0, 0, 46, 108, 10]
#
# self.current_direction = 'N'
# CarCoord(axis0=1, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(0023,5)            R([0, 1]|[1, 0]     ]]
# action = 2, lane = 0
# [2, 1, 76, 0, 1, 40]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=1)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  X(0023,5)            R([0, 1, 2]|[2, 1, 0]]]
# action = 3, lane = 1
# [13, 0, 10, 23, 0, 1]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=2)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [118, 0, 0, 15, 203, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=3)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [161, 0, 0, 197, 0, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=4)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=5)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [66, 0, 0, 31, 51, 0]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=6)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  X(0203,5)            R([0, 1, 2]|[2, 1, 0]]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 4, lane = 0
# [72, 0, 0, 49, 80, 4]
#
# self.current_direction = 'E'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  G()                  G()                 ]
#  [G()                  X(0203,5)            R([0, 1, 2]|[2, 1, 0]]]
# action = 2, lane = 0
# [0, 3, 71, 0, 0, 6]
#
# self.current_direction = 'S'
# CarCoord(axis0=1, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  X(0203,5)            R([0, 1, 2]|[1, 0]  ]]
# action = 3, lane = 2
# [13, 0, 0, 26, 0, 0]
#
# self.current_direction = 'S'
# CarCoord(axis0=2, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 2
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [107, 0, 0, 3, 250, 16]
#
# self.current_direction = 'S'
# CarCoord(axis0=3, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 4, lane = 0
# [131, 0, 0, 75, 148, 15]
#
# self.current_direction = 'S'
# CarCoord(axis0=4, axis1=7)
# DestCoord(axis0=5, axis1=7)
# self.current_lane = 0
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1, 2]|[2, 1, 0] G()                 ]]
# action = 3, lane = 1
# [144, 0, 0, 185, 0, 13]
#
# Episode 7: sum_reward = 78270
#
#
# INITIAL STATE:
#  self.current_direction = 'S'
# CarCoord(axis0=6, axis1=7)
# DestCoord(axis0=6, axis1=7)
# self.current_lane = 3
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# self.current_direction = 'S'
# CarCoord(axis0=6, axis1=7)
# DestCoord(axis0=6, axis1=7)
# self.current_lane = 3
# [[G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 2
# [107, 0, 0, 3, 250, 16]
#
# self.current_direction = 'S'
# CarCoord(axis0=7, axis1=7)
# DestCoord(axis0=6, axis1=7)
# self.current_lane = 2
# [[G()                  X(2200,4)            R([0, 1, 2]|[1, 0]  ]
#  [G()                  R([0, 1]|[3, 2, 1, 0] G()                 ]]
# action = 4, lane = 1
# [114, 0, 0, 72, 115, 27]
#
# self.current_direction = 'S'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=6, axis1=7)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [G()                  X(2200,4)            R([0, 1, 2]|[1, 0]  ]]
# action = 5, lane = 1
# [0, 1, 26, 0, 1, 56]
#
# self.current_direction = 'N'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=6, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [R([0, 1]|[2, 1, 0]   X(2200,4)            G()                 ]]
# action = 0, lane = 1
# [20, 0, 0, 0, 20, 0]
#
# self.current_direction = 'N'
# CarCoord(axis0=7, axis1=7)
# DestCoord(axis0=6, axis1=7)
# self.current_lane = 1
# [[G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]
#  [G()                  R([0, 1, 2, 3]|[1, 0] G()                 ]]
# action = 4, lane = 0
# [114, 0, 0, 13, 214, 0]
#
# Episode 8: sum_reward = 94210
#
#
# INITIAL STATE:
#  self.current_direction = 'E'
# CarCoord(axis0=8, axis1=2)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=2)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [170, 0, 0, 227, 0, 7]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=3)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [154, 0, 0, 2, 224, 9]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=4)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 3, lane = 1
# [195, 0, 0, 213, 0, 82]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=5)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  R([0, 1]|[2, 1, 0]   G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [35, 0, 0, 23, 27, 12]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=6)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[R([0, 1, 2, 3]|[1, 0] X(2200,4)            G()                 ]
#  [G()                  R([0, 1]|[2, 1, 0]   G()                 ]]
# action = 0, lane = 1
# [35, 0, 0, 23, 27, 12]
#
# self.current_direction = 'E'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [R([0, 1, 2, 3]|[1, 0] X(2200,4)            G()                 ]]
# action = 5, lane = 1
# [0, 25, 1, 0, 0, 37]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=7)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  X(2200,4)            R([0, 1]|[3, 2, 1, 0]]]
# action = 4, lane = 0
# [12, 0, 0, 0, 15, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=6)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=5)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  R([0, 1, 2]|[1, 0]   G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 4, lane = 0
# [133, 0, 0, 0, 287, 1]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=4)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1, 2]|[1, 0]   G()                 ]]
# action = 3, lane = 1
# [176, 0, 0, 235, 0, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=3)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  R([0, 1]|[1, 0]      G()                 ]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 4, lane = 0
# [110, 0, 0, 0, 158, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=2)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  X(4020,6)            R([0, 1, 2, 3]|[3, 2, 1, 0]]
#  [G()                  R([0, 1]|[1, 0]      G()                 ]]
# action = 3, lane = 1
# [125, 0, 0, 156, 0, 0]
#
# self.current_direction = 'W'
# CarCoord(axis0=8, axis1=1)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 1
# [[G()                  G()                  G()                 ]
#  [G()                  X(4020,6)            R([0, 1, 2, 3]|[3, 2, 1, 0]]]
# action = 2, lane = 0
# [1, 3, 45, 0, 0, 11]
#
# self.current_direction = 'N'
# CarCoord(axis0=8, axis1=1)
# DestCoord(axis0=7, axis1=1)
# self.current_lane = 0
# [[G()                  R([0, 1, 2, 3]|[3, 2, 1, 0] G()                 ]
#  [G()                  X(4020,6)            R([0, 1]|[1, 0]     ]]
# action = 0, lane = 0
# [21, 0, 0, 18, 0, 0]
#
# Episode 9: sum_reward = 86885
#
#
# 10/10 objects reached their destination. Where next_to_border = 6
